# %%
# mike babb
# 2025 02 01
# do an alpha shape

# %%
# standard
import os

# %%
# external
import geopandas as gpd
import alphashape

# %%
# custom
import run_constants as rc
from utils import *

# %%
fpn = os.path.join(rc.OUTPUT_FILE_PATH, 'test_vertices2.gpkg')

# %%
gdf = gpd.read_file(filename = fpn)

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
point_list = gdf['geometry'].map(lambda x: x.coords[0]).to_list()

# %%
from shapely import Polygon

# %%
from scipy import spatial

# %%
from concave_hull import concave_hull,

# %%
ch = concave_hull(points = point_list)

# %%
my_poly = Polygon(ch)

# %%
test_outcome = gpd.GeoDataFrame(data = {'id':[0]}, geometry = [my_poly], crs = 'epsg:4326')

# %%
write_gdf(gdf = test_outcome, output_file_path=rc.OUTPUT_FILE_PATH,
          output_file_name='test_patch.gpkg')

# %%
gpd.GeoSeries(data = my_poly).plot()
# Out:
# <Axes: >

# %%
from cgal import CGAL_Alpha_shape_2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from cgal import CGAL_Alpha_shape_2
#
# ModuleNotFoundError: No module named 'cgal'

# %%
dt = spatial.Delaunay(points = point_list,furthest_site=False,qhull_options='Fs')

# %%
poly_list = []
for curr_tri in dt.simplices:
    curr_poly = Polygon([point_list[pt] for pt in curr_tri])
    poly_list.append(curr_poly)

# %%
testo = gpd.GeoSeries(poly_list)

# %%
testo.plot()

# %%
import numpy as np

# %%
point_array = np.array(object = point_list)

# %%
point_array

# %%
Polygon(shell = point_array[hull.vertices])

# %%
test_alpha = alphashape.alphashape(points=point_list)

# %%
test_alpha
