# %%
# mike babb
# 2024 06 28
# what streets start and stop?
# step 02: export street nodes

# %%
# standard
import os

# %%
# external
from itertools import combinations, product
import geopandas as gpd
import networkx as nx
import numpy as np
import pandas as pd
import shapely
from shapely.geometry import LineString, Point
from shapely import line_merge

# %%
# custom
from geodataio.geo_operations import points2distance, calculate_initial_compass_bearing

# %% [markdown]
# # load the streetnetwork

# %%
# file path
file_path = 'H:/project/seattle_streets/data/'

# %%
file_name = 'Street_Network_Database_Complete.gpkg'

# %%
fpn = os.path.join(file_path, file_name)

# %%
gdf = gpd.read_file(filename = fpn)

# %%
gdf.columns
# Out:
# Index(['f_intr_id', 't_intr_id', 'snd_id', 'snd_feacode', 'citycode',
#        'stname_id', 'st_code', 'arterial_code', 'segment_type', 'agency_code',
#        'access_code', 'divided_code', 'structure_type', 'legalloc_code',
#        'vehicle_use_code', 'gis_seg_length', 'l_adrs_from', 'l_adrs_to',
#        'r_adrs_from', 'r_adrs_to', 'ord_pre_dir', 'ord_street_name',
#        'ord_street_type', 'ord_suf_dir', 'ord_stname_concat', 'l_city',
#        'l_state', 'l_zip', 'r_city', 'r_state', 'r_zip', 'sndseg_update',
#        'compkey', 'comptype', 'unitid', 'unitid2', 'city_portion', 'geometry'],
#       dtype='object')

# %% [markdown]
# # GENERATE STREET END VERTICES - THESE WILL BE HELPFUL WITH IDENTIFICATION IN SUBSEQUENT STEPS

# %%
def generate_street_end_vertices(gdf:gpd.GeoDataFrame):    
    
    
    # export the vertex of each street end. 
    gdf['start_coord'] = gdf['geometry'].map(lambda x: x.coords[0])
    
    gdf['end_coord'] = gdf['geometry'].map(lambda x: x.coords[-1])
    
    f_node_gdf = gdf[['f_intr_id', 'start_coord']].copy().rename(columns = {'f_intr_id':'node_id',
                                                                           'start_coord':'coord'})
    t_node_gdf = gdf[['t_intr_id', 'end_coord']].copy().rename(columns = {'t_intr_id':'node_id',
                                                                         'end_coord':'coord'})
    
    node_df = pd.concat(objs = [f_node_gdf, t_node_gdf]).drop_duplicates()
    
    # make a gdf
    node_gdf = gpd.GeoDataFrame(data = node_df, geometry =
                                node_df['coord'].map(lambda x: Point(x)), crs = 4326)
    
    node_gdf = node_gdf.drop(labels = ['coord'], axis = 1)

    # remove the start and end coordinates
    gdf = gdf.drop(labels = ['start_coord', 'end_coord'], axis = 1)
    
    return gdf, node_gdf

# %%
# can we generate the vertices? yes... but let's check what type of geometry we are working with
gdf['geometry'].map(lambda x: x.geom_type).value_counts()
# Out:
# geometry
# MultiLineString    34378
# Name: count, dtype: int64

# %%
# everything is a multiline string??? is that necessary?

# %%
test_gdf = gdf.explode()

# %%
test_gdf.shape
# Out:
# (34378, 38)

# %%
# nope! Let's use the .explode() function to convert things to a LineString

# %%
gdf = test_gdf.copy()

# %%
gdf['geometry'].geom_type.value_counts()
# Out:
# LineString    34378
# Name: count, dtype: int64

# %%
gdf, node_gdf = generate_street_end_vertices(gdf = gdf)

# %%
output_file_name = 'Street_Network_Nodes.gpkg'

# %%
ofpn = os.path.join(file_path, output_file_name)

# %%
node_gdf.to_file(filename = ofpn)

# %% [markdown]
# # import the classified streets - this classifies streets without a classification.

# %%
file_name = 'blank_street_type_modified.xlsx'

# %%
fpn = os.path.join(file_path, file_name)

# %%
blank_street_type_df = pd.read_excel(io = fpn)

# %%
blank_street_type_df.head()
# Out:
#    ord_stname_concat ord_st_type
# 0   NE SUNRISE VISTA          ST
# 1       NW ESPLANADE          ST
# 2         BROADWAY E          ST
# 3  FAUNTLEE CREST SW          ST
# 4    NE FOREST VISTA          ST

# %%
gdf['ord_street_type'].unique()
# Out:
# array(['AVE', 'CT', 'ST', 'PL', 'LN', 'RD', 'DR', 'WAY', 'PKWY', 'BLVD',
#        'CIR', 'TER', None, 'AL', 'RP', 'LOOP', 'OP', 'TRL', 'BR', 'ET',
#        'VIEW', 'HWY', 'PZ', 'MALL'], dtype=object)

# %%
gdf = pd.merge(left = gdf, right = blank_street_type_df, how = 'left')

# %%
gdf.loc[gdf['ord_st_type'].isna(), 'ord_st_type'] = gdf.loc[gdf['ord_st_type'].isna(), 'ord_street_type']

# %%
gdf.columns
# Out:
# Index(['f_intr_id', 't_intr_id', 'snd_id', 'snd_feacode', 'citycode',
#        'stname_id', 'st_code', 'arterial_code', 'segment_type', 'agency_code',
#        'access_code', 'divided_code', 'structure_type', 'legalloc_code',
#        'vehicle_use_code', 'gis_seg_length', 'l_adrs_from', 'l_adrs_to',
#        'r_adrs_from', 'r_adrs_to', 'ord_pre_dir', 'ord_street_name',
#        'ord_street_type', 'ord_suf_dir', 'ord_stname_concat', 'l_city',
#        'l_state', 'l_zip', 'r_city', 'r_state', 'r_zip', 'sndseg_update',
#        'compkey', 'comptype', 'unitid', 'unitid2', 'city_portion', 'geometry',
#        'ord_st_type'],
#       dtype='object')

# %%
gdf['ord_st_type'].unique()
# Out:
# array(['AVE', 'CT', 'ST', 'PL', 'LN', 'RD', 'DR', 'WAY', 'PKWY', 'BLVD',
#        'CIR', 'TER', 'AL', 'RP', 'LOOP', 'SR', 'IS', 'OP', 'TRL', 'RR',
#        'BR', 'WKWY', 'ET', 'STCR', 'VIEW', 'FLYOVER', 'HWY', 'RN', 'PZ',
#        'MALL'], dtype=object)

# %% [markdown]
# # keep only streets in Seattle

# %%
gdf = gdf.loc[(gdf['l_city'] == 'SEATTLE') |
(gdf['r_city'] == 'SEATTLE'), :].copy()

# %% [markdown]
# # WRITE THE FULL SEATTLE STREETS TO DISK

# %%
output_file_name = 'Street_Network_Database_Seattle_Full.gpkg'

# %%
ofpn = os.path.join(file_path, output_file_name)

# %%
gdf.to_file(filename = ofpn, driver = 'GPKG', index = False)

# %% [markdown]
# # EXPORT THE INDIVIDUAL STREET PORTIONS TO MAKE THE DIFFERENT SECTIONS

# %%
# after performing some analysis in GIS, we can quickly identify the central

# %%
file_name = 'Street_Network_Database_Seattle_Central_Streets.csv'

# %%
fpn = os.path.join(file_path, file_name)

# %%
cs_df = pd.read_csv(filepath_or_buffer=fpn)

# %%
cs_df = cs_df.drop(labels = ['fid'], axis =  1)

# %%
# working_gdf
# winnow down the list of streets to get what we're looking for 

q_str = 'snd_feacode in (1, 5) and st_code in (0, ) and city_portion != \'WB\''
wgdf = gdf.query(expr = q_str)

# %%
output_file_path = 'H:/project/seattle_streets/data/city_section'

if not os.path.exists(output_file_path):
    os.makedirs(output_file_path)

data_list = []
geom_list = []
for cp in wgdf['city_portion'].unique().tolist():
    print(cp)
    if cp == ' ':
        temp_geoms = wgdf.loc[(wgdf['snd_id'].isin(cs_df['snd_id'])) &
        (wgdf['city_portion'] == cp), 'geometry']
    else:
        temp_geoms = wgdf.loc[wgdf['city_portion'] == cp, 'geometry']
    
    
    # # create the concave hull
    # point_cloud = []
    # for tg in temp_geoms:
    #     for coords in tg.coords:
    #         point_cloud.append(Point(coords))
    # point_cloud = shapely.unary_union(geometries = point_cloud)
    # ccv_hull = shapely.concave_hull(geometry = point_cloud)    
    # temp_list = [cp, 'concave']
    # data_list.append(temp_list)
    # geom_list.append(ccv_hull)

    # create the convex hull
    geoms = shapely.unary_union(geometries = temp_geoms)
    cvx_hull = shapely.convex_hull(geometry = geoms)
    temp_list = [cp, 'convex']
    data_list.append(temp_list)
    geom_list.append(cvx_hull)
# Out:
# S
# E
# NW
# N
#
# NE
# SW
# W

# %%
output_gdf = gpd.GeoDataFrame(data = data_list, columns = ['city_portion', 'hull_type'], geometry = geom_list, crs = 'epsg:4326')

# %%
output_file_path = 'H:/project/seattle_streets/data/'

# %%
file_name = 'city_sections.gpkg'

# %%
ofpn = os.path.join(output_file_path, file_name)

# %%
output_gdf.to_file(filename = ofpn, driver = 'GPKG', index = False)

# %% [markdown]
# # REMOVE "STREETS" THAT ARE REALLY SHORT TURNOUTS AND WALKING PATHS

# %% [markdown]
# AL: Alley
# TRL: Trail
# CIR: Circle
# TER: Terrace
# OP: Overpass
# RP: Ramp
# ET: Extension
# RN: TURN

# %%
gdf.columns
# Out:
# Index(['f_intr_id', 't_intr_id', 'snd_id', 'snd_feacode', 'citycode',
#        'stname_id', 'st_code', 'arterial_code', 'segment_type', 'agency_code',
#        'access_code', 'divided_code', 'structure_type', 'legalloc_code',
#        'vehicle_use_code', 'gis_seg_length', 'l_adrs_from', 'l_adrs_to',
#        'r_adrs_from', 'r_adrs_to', 'ord_pre_dir', 'ord_street_name',
#        'ord_street_type', 'ord_suf_dir', 'ord_stname_concat', 'l_city',
#        'l_state', 'l_zip', 'r_city', 'r_state', 'r_zip', 'sndseg_update',
#        'compkey', 'comptype', 'unitid', 'unitid2', 'city_portion', 'geometry',
#        'ord_st_type'],
#       dtype='object')

# %%
# remove streets of the following type
street_type_to_remove = [ 'AL', 'TRL', 'OP', 'IS', 'SR', 'RR', 'FLYOVER', 'STCR', 'ET', 'RN', 'RP']

# %%
gdf.shape
# Out:
# (27405, 40)

# %%
gdf = gdf.loc[-gdf['ord_street_type'].isin(street_type_to_remove), :].copy()

# %%
gdf.shape
# Out:
# (27405, 40)

# %%
gdf['ord_street_type'].unique()
# Out:
# array(['AVE', 'ST', 'PL', 'LN', 'RD', 'WAY', 'PKWY', 'DR', 'CT', 'BLVD',
#        'CIR', 'TER', None, 'BR', 'VIEW', 'LOOP', 'PZ', 'MALL'],
#       dtype=object)

# %% [markdown]
# # LABEL STREET SUB-GROUPS

# %%
gdf.columns
# Out:
# Index(['f_intr_id', 't_intr_id', 'snd_id', 'snd_feacode', 'citycode',
#        'stname_id', 'st_code', 'arterial_code', 'segment_type', 'agency_code',
#        'access_code', 'divided_code', 'structure_type', 'legalloc_code',
#        'vehicle_use_code', 'gis_seg_length', 'l_adrs_from', 'l_adrs_to',
#        'r_adrs_from', 'r_adrs_to', 'ord_pre_dir', 'ord_street_name',
#        'ord_street_type', 'ord_suf_dir', 'ord_stname_concat', 'l_city',
#        'l_state', 'l_zip', 'r_city', 'r_state', 'r_zip', 'sndseg_update',
#        'compkey', 'comptype', 'unitid', 'unitid2', 'city_portion', 'geometry',
#        'ord_st_type', 'snd_group'],
#       dtype='object')

# %%
def identify_street_groups(gdf:gpd.GeoDataFrame, s_names:list = None):
    
    if s_names is None:
        s_names = gdf['ord_stname_concat'].unique().tolist()

    gdf['snd_group'] = int(0)
    
    snd_group_count = -1
    for sn in s_names:
        # get a street by name
        print(sn)
        # subset the gdf
        temp_gdf = gdf.loc[gdf['ord_stname_concat'] == sn, :].copy()        
        
        # build a graph to find (dis)connected components: this is an easy way to find portions of a street that are not connected to each other
        g = nx.from_pandas_edgelist(df = temp_gdf, source = 'f_intr_id', target = 't_intr_id', edge_attr=True)
        # do I need to save the graph?
        n_connected_components = nx.number_connected_components(g)        
        
        for c in nx.connected_components(g):
            # c is the sub graph
            # this is the edge data
            edge_data_list = g.subgraph(c).edges.data()
            # this marks the street(s) in each sub group
            snd_id_list = []
            for edl in edge_data_list:                        
                snd_id_list.append(edl[2]['snd_id'])
            snd_group_count += 1
            # this will update the gdf per street name with the groups of streets
            gdf.loc[gdf['snd_id'].isin(snd_id_list), 'snd_group'] = snd_group_count 

    return gdf

# %%
gdf = identify_street_groups(gdf = gdf)
# Out:
# 8TH AVE S
# BELMONT AVE E
# E PIKE ST
# NW 63RD ST
# MCCLINTOCK AVE S
# NORTH PARK AVE N
# 8TH AVE
# 37TH AVE S
# 25TH AVE NE
# S WAITE ST
# NE 107TH ST
# NW 42ND ST
# LINDEN AVE N
# NE 40TH ST
# FAUNTLEROY PL SW
# W GALER ST
# SW WALKER ST
# 20TH AVE NW
# S BYRON ST
# S FOREST ST
# VICTORY LN NE
# 18TH AVE SW
# 26TH AVE NW
# 29TH AVE S
# 27TH AVE NE
# 17TH AVE NW
# KIRKWOOD PL N
# 7TH AVE NW
# NE 45TH ST
# ROWAN RD S
# 28TH AVE SW
# S 130TH ST
# 38TH AVE E
# E MARION ST
# S HOLLY ST
# N 95TH ST
# E OLIVE ST
# E LOUISA ST
# E REPUBLICAN ST
# 15TH AVE SW
# CEDAR ST
# 5TH AVE W
# 45TH AVE NE
# W RAYE ST
# S DAKOTA ST
# NE 91ST ST
# NW 70TH ST
# 18TH AVE NE
# 48TH AVE SW
# S 102ND ST
# W FULTON ST
# NE 68TH ST
# W RUFFNER ST
# 35TH AVE
# 46TH AVE SW
# 8TH AVE NE
# CHERRY ST
# 21ST AVE S
# 37TH AVE W
# ALKI AVE SW
# DAYTON AVE N
# SW 102ND ST
# N 90TH ST
# SW ANDOVER ST
# FREMONT AVE N
# THOMAS ST
# 27TH AVE W
# WESTERN AVE
# SW DAKOTA ST
# STONE AVE N
# NW 94TH ST
# NE 123RD ST
# 24TH AVE W
# NE 130TH PL
# NW 62ND ST
# 48TH AVE S
# 3RD AVE NE
# WESTMONT WAY W
# 37TH AVE SW
# FAIRVIEW AVE E
# NE 55TH ST
# 46TH AVE S
# NW 105TH ST
# 47TH AVE SW
# 28TH AVE NE
# NW 120TH ST
# 12TH AVE NE
# 25TH AVE
# 45TH AVE SW
# 42ND AVE S
# E COLUMBIA ST
# WOODLAWN AVE N
# NE CAMPUS PKWY
# ASHWORTH AVE N
# S MASSACHUSETTS ST
# E CRESCENT DR
# S ELMWOOD PL
# W MCGRAW ST
# SW CHARLESTOWN ST
# PERKINS LN W
# SUMMIT AVE E
# ANN ARBOR AVE NE
# 51ST AVE S
# 22ND AVE S
# 20TH AVE NE
# 33RD AVE NE
# MYERS WAY S
# S IRVING ST
# S LANGSTON RD
# LAKE RIDGE DR S
# SW KENYON ST
# N 64TH ST
# NE 67TH ST
# SW EDMUNDS ST
# 25TH AVE S
# NE 98TH ST
# 6TH AVE SW
# 10TH AVE S
# E JANSEN CT
# CALIFORNIA AVE SW
# 40TH AVE SW
# NW 68TH ST
# NE 117TH ST
# SW BRANDON ST
# CORNELL AVE S
# 49TH AVE NE
# PROSPECT ST
# 43RD PL SW
# SW 104TH ST
# MELROSE AVE E
# 14TH AVE S
# N 57TH ST
# NW 121ST ST
# S DEARBORN ST
# E PROSPECT ST
# 41ST AVE NE
# 6TH AVE NW
# 57TH AVE SW
# 30TH AVE W
# 19TH AVE SW
# 49TH AVE SW
# 22ND AVE E
# MERIDIAN AVE N
# 35TH AVE NW
# 1ST AVE
# SW GRAYSON ST
# GARFIELD ST
# 17TH AVE SW
# 38TH AVE S
# SW STEVENS ST
# N 37TH ST
# 42ND AVE W
# GREENWOOD AVE N
# 39TH AVE SW
# NE 77TH ST
# 55TH AVE S
# 52ND AVE SW
# 53RD AVE S
# EVANSTON AVE N
# 2ND AVE N
# E DENNY WAY
# 82ND AVE S
# INTERLAKE AVE N
# 36TH AVE NW
# 28TH AVE NW
# NE 62ND ST
# NE 115TH ST
# E NEWTON ST
# 6TH AVE W
# S 112TH ST
# 20TH AVE
# N 137TH ST
# S HANFORD ST
# SW 106TH ST
# W THURMAN ST
# NE 97TH ST
# SW LANDER ST
# S HILL ST
# NE 71ST ST
# VIRGINIA ST
# E ROANOKE ST
# NW 53RD ST
# LEE ST
# E HOWELL ST
# W BLAINE ST
# SW MYRTLE ST
# 3RD AVE SW
# 34TH AVE S
# BROADMOOR DR E
# 3RD AVE S
# 5TH AVE SW
# 41ST AVE SW
# SW TRENTON ST
# NE 52ND ST
# NE 74TH ST
# NW 90TH ST
# 34TH AVE
# SW CAMBRIDGE ST
# SHILSHOLE AVE NW
# S 106TH ST
# N 34TH ST
# 24TH AVE S
# S 123RD ST
# 44TH AVE S
# PHINNEY AVE N
# N 92ND ST
# DECATUR PL S
# 4TH AVE N
# S 122ND ST
# S PEARL ST
# HARRIS PL S
# DIXON DR S
# NW 127TH ST
# S WELLER ST
# 11TH AVE NE
# NE 83RD ST
# NE 51ST ST
# SW WAITE ST
# SW CLOVERDALE ST
# NE 43RD ST
# S CAMBRIDGE ST
# S BRANDON ST
# S ANGELINE ST
# N 55TH ST
# S HAZEL CT
# 39TH AVE NE
# 9TH AVE W
# 80TH AVE S
# W ELMORE ST
# S FRONTENAC ST
# NE 142ND ST
# S INDUSTRIAL WAY
# OAKWOOD AVE S
# S 129TH ST
# NW 59TH ST
# WILLARD AVE W
# 9TH AVE NW
# LAKE WASHINGTON BLVD S
# 11TH AVE NW
# 10TH AVE W
# SW 115TH ST
# 57TH AVE S
# S 126TH ST
# 32ND AVE S
# 42ND AVE E
# S STEVENS ST
# 76TH AVE S
# 79TH AVE S
# S FIDALGO ST
# VINE ST
# S 118TH PL
# 56TH AVE NE
# 38TH AVE W
# 5TH AVE S
# N 59TH ST
# SW OREGON ST
# E UNION ST
# S PLUM ST
# 50TH AVE SW
# 32ND AVE NE
# 4TH AVE S
# BOREN AVE N
# WETMORE AVE S
# 54TH AVE S
# UNIVERSITY CIR NE
# E JEFFERSON ST
# CORLISS AVE N
# 75TH AVE S
# N 41ST ST
# 57TH AVE NE
# 38TH AVE NE
# 16TH AVE S
# 36TH AVE NE
# NE 73RD ST
# 66TH AVE S
# S HENDERSON ST
# 26TH AVE S
# 14TH AVE NW
# NW GOLDEN PL
# S 115TH ST
# S 124TH ST
# N 82ND ST
# TERRY AVE
# COLUMBIA ST
# NW 66TH ST
# S HAZEL ST
# 14TH AVE NE
# 29TH AVE W
# EASTERN AVE N
# 20TH AVE E
# MARY AVE NW
# HARRISON ST
# N 36TH ST
# S WALKER ST
# NE 86TH ST
# 38TH AVE SW
# S ALASKA ST
# N NORTHLAKE PL
# 1ST AVE NE
# 18TH AVE S
# BOYLSTON AVE
# GAY AVE W
# 24TH AVE NE
# 40TH AVE NE
# 73RD LN S
# SW 105TH ST
# SW HINDS ST
# NE 57TH ST
# NW 75TH ST
# N 127TH ST
# N 39TH ST
# 18TH AVE E
# 19TH AVE S
# 16TH AVE
# 34TH AVE NW
# 77TH AVE S
# N 48TH ST
# NE 61ST ST
# NE 103RD ST
# S HUDSON ST
# N 140TH ST
# NW 77TH ST
# 62ND AVE S
# 3RD AVE
# 31ST AVE NE
# 6TH AVE N
# MARION ST
# SW 103RD ST
# NW BLUE RIDGE DR
# 2ND AVE NE
# CASCADIA AVE S
# NW 130TH ST
# NE 106TH ST
# NW 64TH ST
# S FOUNTAIN ST
# MONTVALE CT W
# 10TH AVE SW
# 5TH PL S
# NW 112TH ST
# SW 112TH ST
# REPUBLICAN ST
# 61ST AVE S
# NW 84TH ST
# WHITMAN AVE N
# NW 92ND ST
# S GRAND ST
# W CROCKETT ST
# S CHARLES ST
# 44TH AVE SW
# 40TH AVE W
# 20TH AVE S
# MILITARY RD S
# 69TH PL S
# 49TH AVE S
# 50TH AVE NE
# 31ST AVE W
# 19TH AVE E
# 43RD AVE E
# 24TH AVE
# STENDALL DR N
# W HIGHLAND DR
# S ANDOVER ST
# NE 60TH ST
# S ORCAS ST
# S VAN DYKE RD
# E PINE ST
# EXETER AVE NE
# 4TH AVE NW
# 1ST AVE N
# 59TH AVE S
# DENVER AVE S
# 33RD AVE S
# 39TH AVE S
# 53RD AVE NE
# 29TH AVE E
# 11TH AVE E
# 5TH AVE NE
# 3RD AVE N
# 20TH AVE SW
# FOREST AVE S
# HOLLY TER S
# NE 89TH ST
# 44TH AVE NE
# NW 60TH ST
# W BARRETT ST
# NE 130TH ST
# N 52ND ST
# SW HUDSON ST
# S MAIN ST
# LYNN ST
# 15TH AVE
# CRANE DR W
# 3RD AVE W
# N 72ND ST
# E WARD ST
# S WINTHROP ST
# S CONCORD ST
# NE 50TH ST
# UNIVERSITY ST
# S PILGRIM ST
# N 102ND ST
# 7TH AVE S
# 13TH AVE S
# 42ND AVE SW
# 61ST AVE NE
# 24TH AVE SW
# 69TH AVE S
# N 107TH ST
# NW 49TH ST
# E HELEN ST
# S WASHINGTON ST
# 25TH AVE E
# SW FINDLAY ST
# W CLISE CT
# WARREN AVE N
# E ROY ST
# PALATINE AVE N
# S DAWSON ST
# S MCCLELLAN ST
# 55TH AVE NE
# 36TH AVE S
# 19TH AVE NW
# NE SUNRISE VISTA
# 34TH AVE SW
# 7TH AVE SW
# SW TILLMAN ST
# 39TH AVE E
# SEELYE CT S
# SW HOLLY ST
# W WHEELER ST
# E GALER ST
# S ATLANTIC ST
# N 71ST ST
# W SMITH ST
# S SPOKANE ST
# SW MANNING ST
# N 49TH ST
# E HIGHLAND DR
# 32ND AVE
# RANDOLPH AVE
# 45TH AVE S
# 42ND AVE NE
# 31ST AVE SW
# 41ST AVE E
# 24TH AVE E
# S BAYVIEW ST
# FAIRWAY DR NE
# CORWIN PL S
# 36TH AVE W
# HIRAM PL NE
# E BOSTON ST
# BOYD PL SW
# UNION ST
# DENSMORE AVE N
# BAGLEY AVE N
# NOB HILL AVE N
# 21ST AVE NW
# 9TH AVE
# 2ND AVE S
# LOTUS AVE SW
# MARINE VIEW DR SW
# LENORA PL N
# LAKE SHORE BLVD NE
# DEXTER AVE N
# S MORGAN ST
# NW 132ND ST
# NE SURBER DR
# NW 137TH ST
# 52ND AVE S
# 16TH AVE SW
# S MEAD ST
# 11TH AVE S
# 25TH AVE SW
# N 115TH ST
# E MERCER ST
# S MOUNT BAKER BLVD
# NW 95TH ST
# 22ND AVE W
# NW WOODBINE PL
# NE 69TH ST
# 4TH AVE W
# 51ST AVE NE
# 13TH AVE E
# 31ST AVE S
# 36TH AVE E
# E BLAINE ST
# NE 78TH ST
# W CREMONA ST
# N 75TH ST
# NW BOWDOIN PL
# SW BARTON ST
# W BOSTON ST
# S BANGOR ST
# 29TH AVE SW
# 23RD AVE NE
# SW 108TH ST
# 8TH AVE W
# S THISTLE ST
# 16TH AVE E
# 11TH AVE SW
# ELLINOR DR W
# 14TH AVE W
# 1ST AVE NW
# ORANGE PL N
# 41ST AVE S
# NW 85TH ST
# W BERTONA ST
# MAYNARD AVE S
# BROADWAY CT
# S STACY ST
# NE 44TH ST
# NW 55TH ST
# CHAPIN PL N
# 19TH AVE NE
# 37TH AVE NE
# 43RD AVE NE
# SW 107TH ST
# 5TH AVE NW
# 22ND AVE NE
# 43RD PL NE
# 32ND AVE SW
# 12TH AVE E
# 31ST AVE
# 9TH AVE NE
# NE 66TH ST
# NW 117TH ST
# W GLENMONT LN
# NE 64TH ST
# N 44TH ST
# S FERDINAND ST
# LAKEVIEW LN NE
# SW ATLANTIC ST
# SW HENDERSON ST
# NW 50TH ST
# 2ND AVE NW
# CROCKETT ST
# ALTON AVE NE
# 2ND AVE SW
# BEACON AVE S
# 13TH AVE SW
# GOODELL PL S
# SW BRADFORD ST
# E SPRUCE ST
# N 42ND ST
# N 122ND ST
# 43RD AVE W
# N 117TH ST
# 26TH AVE SW
# NE 124TH ST
# MOUNTAIN DR W
# NE 82ND ST
# S CHICAGO ST
# 35TH AVE S
# SW DOUGLAS PL
# 28TH PL W
# 5TH AVE N
# PAISLEY PL NE
# S ELMGROVE ST
# N 67TH ST
# S SNOQUALMIE ST
# THACKERAY PL NE
# S IDAHO ST
# JONES AVE NW
# 32ND AVE E
# 28TH AVE S
# S HINDS ST
# 12TH AVE NW
# S LUCILE ST
# SW 98TH ST
# N 61ST ST
# S WARSAW ST
# NE 88TH ST
# WOODLAND PARK AVE N
# 11TH AVE
# N 46TH ST
# S SULLIVAN ST
# S BARTON ST
# SW ELMGROVE ST
# 1ST AVE W
# NE 58TH ST
# NE 63RD ST
# 4TH AVE NE
# 12TH AVE
# PARKSIDE DR E
# 9TH AVE SW
# E HOWE ST
# NE 80TH ST
# NE 135TH ST
# S DIRECTOR ST
# 25TH AVE NW
# 27TH AVE E
# 30TH AVE NE
# 17TH AVE
# E SPRING ST
# SW JUNEAU ST
# W LAWTON ST
# N 88TH ST
# N 106TH ST
# N 122ND PL
# ETRURIA ST
# 33RD AVE W
# S JACKSON ST
# E HAMLIN ST
# NE 79TH ST
# N 51ST ST
# W KINNEAR PL
# S LANE ST
# NE 140TH ST
# BIGELOW AVE N
# N 54TH ST
# 6TH AVE NE
# NW 44TH ST
# E SAINT ANDREWS WAY
# SHENANDOAH DR E
# S HOLDEN ST
# OBERLIN AVE NE
# W ARMOUR ST
# W MCCORD PL
# 13TH AVE
# 2ND AVE W
# S ORCHARD ST
# RANDOLPH PL
# 56TH AVE SW
# N 47TH ST
# YORK RD S
# NEWTON ST
# S MYRTLE ST
# S OREGON ST
# DUNCAN AVE S
# S MAYFLOWER ST
# NE 118TH ST
# NW 73RD ST
# NE RAVENNA BLVD
# NE 137TH ST
# 30TH AVE
# S 120TH ST
# S SOUTHERN ST
# W GARFIELD ST
# S ALASKA PL
# S ESTELLE ST
# BELLA VISTA AVE S
# NE 143RD ST
# MONTAVISTA PL W
# 6TH AVE S
# 25TH AVE W
# MINOR AVE
# 21ST AVE E
# CARLETON AVE S
# SW 100TH ST
# S 101ST ST
# NE CROWN PL
# 22ND AVE SW
# SHERWOOD RD NW
# SW SEATTLE ST
# 12TH AVE SW
# 8TH AVE SW
# 21ST AVE SW
# S HOLGATE ST
# ALBION PL N
# W LYNN ST
# S COLLEGE ST
# E LEE ST
# NE WINDERMERE RD
# SW OLGA ST
# 26TH AVE E
# N 103RD ST
# 8TH AVE NW
# 70TH PL S
# 35TH AVE W
# E ALDER ST
# N 109TH ST
# E SHELBY ST
# S HORTON ST
# NW 48TH ST
# NW 58TH ST
# N 97TH ST
# EYRES PL W
# NW ESPLANADE
# 17TH AVE NE
# N 45TH ST
# LATONA AVE NE
# NE 90TH ST
# 68TH AVE S
# 7TH AVE
# 61ST PL S
# SUNNYSIDE AVE N
# CHELAN AVE SW
# 33RD AVE SW
# 30TH AVE S
# FRANKLIN AVE E
# NE 113TH ST
# NE 70TH ST
# S KENYON ST
# S BENNETT ST
# E MCGRAW ST
# 34TH PL SW
# S CAMANO PL
# S CORGIAT DR
# 26TH AVE NE
# SW 110TH ST
# NW 46TH ST
# N 143RD ST
# S SPENCER ST
# 56TH PL SW
# 38TH AVE
# NW 74TH ST
# MIDVALE AVE N
# 60TH AVE SW
# PINE ST
# 35TH AVE E
# NE 47TH ST
# 12TH AVE S
# NE 120TH ST
# HIGHLAND DR
# HALLADAY ST
# JOHN ST
# N 62ND ST
# SW SOUTHERN ST
# NW VERNON PL
# 26TH AVE
# 48TH PL NE
# BATTERY ST
# 5TH AVE
# S 96TH ST
# S CARVER ST
# N 43RD ST
# N 77TH ST
# NE 100TH ST
# S FARRAR ST
# S JUNEAU ST
# SW HILL ST
# S 125TH ST
# 33RD AVE E
# W EMERSON ST
# NE 72ND ST
# S PORTLAND ST
# NE 75TH ST
# OCCIDENTAL AVE S
# 53RD AVE SW
# 14TH CT S
# CREST DR NE
# SW DAWSON ST
# S NORFOLK ST
# N 83RD ST
# HUGHES AVE SW
# NW 54TH ST
# GILMAN AVE W
# MCGRAW ST
# S WILLOW ST
# NW 57TH ST
# LEXINGTON PL S
# NE 136TH ST
# N 105TH ST
# S TAFT ST
# SW PRINCE ST
# BROOKLYN AVE NE
# E GARFIELD ST
# SW HANFORD ST
# BEACH DR SW
# 34TH AVE E
# 30TH AVE SW
# SEOLA BEACH DR SW
# GRAND AVE
# FEDERAL AVE E
# ALDER ST
# MAPLEWOOD PL SW
# AIKINS AVE SW
# SUMMIT AVE
# NE 95TH ST
# S SUNNY VIEW DR
# NW 51ST ST
# NE 46TH ST
# SW OTHELLO ST
# NW 56TH ST
# 48TH AVE NE
# EAGLE ST
# 24TH PL W
# NW 67TH ST
# S KENNY ST
# HILLMAN PL NE
# 54TH AVE NE
# 21ST AVE
# NE 92ND ST
# GARLOUGH AVE SW
# W HAYES ST
# NE 105TH PL
# SW MASSACHUSETTS ST
# WESTLAKE AVE
# 14TH AVE SW
# LEDROIT CT SW
# 7TH AVE W
# ROOSEVELT WAY NE
# S COOPER ST
# LOTUS PL S
# W CRAMER ST
# BELVIDERE AVE SW
# DEWEY PL E
# NE 85TH ST
# LOYAL AVE NW
# NESBIT AVE N
# W BARRETT LN
# 10TH AVE NW
# NE 87TH ST
# WALLINGFORD AVE N
# SW DONOVAN ST
# W FORT ST
# N 86TH ST
# W LEE ST
# S 104TH ST
# N 73RD ST
# S ROSE ST
# NW 122ND ST
# SW ARROYO CT
# NE 42ND ST
# SW ARROYO DR
# NE 108TH PL
# BURKE AVE N
# LEROY PL S
# NE 105TH ST
# 26TH AVE W
# 17TH AVE S
# MELROSE AVE
# YAKIMA AVE S
# S EDDY ST
# NW 90TH PL
# NEWELL ST
# MOUNT ADAMS PL S
# E SHORE DR
# NW CARKEEK PARK RD
# NE 45TH PL
# RENTON AVE S
# W MCGRAW PL
# S 117TH ST
# SW GENESEE ST
# 7TH AVE NE
# S JUDKINS ST
# 18TH AVE
# NORTHROP PL SW
# MARINE AVE SW
# W HOWE ST
# 3RD PL NW
# NE 81ST ST
# IVANHOE PL NE
# 51ST AVE SW
# ORIN CT N
# 27TH AVE
# 22ND AVE NW
# S TRENTON ST
# MAIDEN LN E
# S FLETCHER ST
# W COMSTOCK ST
# AUBURN PL E
# VALENTINE PL S
# N 120TH ST
# MCKINLEY PL N
# N 128TH ST
# S AMERICUS ST
# S WEBSTER ST
# LAKESIDE AVE NE
# LAKE RIDGE PL S
# 37TH AVE
# S FINDLAY ST
# N 141ST ST
# E CALHOUN ST
# SW ROSE ST
# 74TH AVE S
# 29TH AVE NE
# N BOWDOIN PL
# S DELAPPE PL
# S FERRIS PL
# SW DIRECTOR ST
# DIAGONAL AVE S
# S ADAMS ST
# S AUSTIN ST
# 34TH AVE W
# 10TH AVE
# SW THISTLE ST
# BLAINE ST
# AUBURN AVE S
# NW 100TH ST
# 18TH AVE NW
# NE 110TH ST
# E FIR ST
# S EDMUNDS ST
# WELLINGTON AVE
# NW 110TH ST
# E HARRISON ST
# E CONOVER CT
# PIKE PL
# BAKER AVE NW
# RAYE ST
# EARL AVE NW
# LETITIA AVE S
# S 127TH ST
# W BOTHWELL ST
# E THOMAS ST
# NE 138TH ST
# N 38TH ST
# SW WINTHROP ST
# E SENECA ST
# S 100TH ST
# N 87TH ST
# SW FRONTENAC ST
# SW ADMIRAL WAY
# 15TH AVE NW
# SW IDAHO ST
# 36TH AVE SW
# NW 101ST ST
# E LYNN ST
# NW 83RD ST
# TROLL AVE N
# ARAPAHOE PL W
# S 122ND PL
# 10TH AVE E
# RAVENNA AVE NE
# 47TH AVE NE
# LEXINGTON WAY E
# SW AUSTIN ST
# NE 35TH ST
# S PARKLAND PL
# BOYLSTON AVE E
# 14TH PL NE
# RADFORD AVE NW
# NE 125TH ST
# 60TH AVE NE
# SHORELAND DR S
# NE 48TH ST
# ALOHA ST
# COLUMBIA DR S
# FREMONT LN N
# PATTEN PL W
# 21ST AVE NE
# 36TH AVE
# SW 107TH WAY
# NE 94TH ST
# 22ND AVE
# NE 36TH ST
# E TERRACE ST
# NE 104TH ST
# WALNUT AVE SW
# S FONTANELLE ST
# N 110TH ST
# 29TH AVE NW
# S KING ST
# 16TH AVE W
# 16TH AVE NW
# S 108TH PL
# SW ALASKA ST
# SW HOLGATE ST
# S NEBRASKA ST
# PARK RD NE
# 3RD AVE NW
# HAYES ST
# N 70TH ST
# NE PARK RD
# W THOMAS ST
# SW WEBSTER ST
# S GENESEE ST
# MINOR AVE N
# SW EDDY ST
# NW 97TH ST
# NW ROUNDHILL CIR
# NE 54TH ST
# 30TH AVE NW
# HAMPTON RD S
# W JAMESON ST
# 46TH AVE NE
# 56TH PL NE
# BOSTON ST
# S PRENTICE ST
# NW 131ST ST
# N 74TH ST
# N 135TH ST
# 37TH AVE NW
# STEWART ST
# 14TH AVE E
# N 121ST ST
# DIBBLE AVE NW
# LUTHER AVE S
# 39TH AVE W
# 34TH AVE NE
# S STATE ST
# NE 33RD ST
# E OLIN PL
# S CHARLESTOWN ST
# 15TH AVE S
# NE 59TH ST
# EASTMONT WAY W
# NW 87TH ST
# FAUNTLEROY WAY SW
# 1ST PL NE
# 29TH AVE
# S RAYMOND ST
# E MARTIN ST
# 26TH PL W
# GALER ST
# SW CONCORD ST
# 63RD AVE NE
# S 117TH PL
# N 135TH PL
# 33RD AVE NW
# QUEEN ANNE AVE N
# MERIDIAN PL N
# CONSTANCE DR W
# WOODLEY AVE S
# SW 99TH ST
# N 66TH ST
# S GRAHAM ST
# SW 111TH ST
# W ROY ST
# S BRIGHTON ST
# NW 107TH ST
# 62ND AVE SW
# CORSON AVE S
# W HARLEY ST
# SW DONALD ST
# NW 43RD ST
# N 101ST ST
# E JAMES CT
# 28TH AVE
# SW WARSAW ST
# SW RAYMOND ST
# EDGEWEST DR NW
# S SUNNYCREST RD
# NW 144TH ST
# SW SNOQUALMIE ST
# N 35TH ST
# SW FONTANELLE ST
# 32ND AVE W
# COURTLAND PL S
# N 113TH PL
# N 60TH ST
# INVERNESS DR NE
# S NORMAN ST
# N 58TH ST
# 25TH PL W
# LIMA TER S
# SW 113TH ST
# PRESCOTT AVE SW
# URSULA PL S
# W PARKMONT PL
# HUBBELL PL
# NW 116TH ST
# 60TH AVE S
# KEEN WAY N
# SW WILLOW ST
# NE LONGWOOD PL
# ALVIN PL NW
# NW 89TH PL
# MAYFAIR AVE N
# 10TH PL NE
# NW 71ST ST
# 1ST AVE SW
# WICKSTROM PL SW
# N ALLEN PL
# S RYAN ST
# S RIVER ST
# 16TH AVE NE
# BROADWAY E
# 46TH AVE W
# SYLVAN PL NW
# RUSTIC RD S
# 23RD PL NE
# CLEOPATRA PL NW
# S 103RD ST
# 1ST AVE S
# S 131ST PL
# S BANGOR CT
# W MANSELL ST
# S 112TH PL
# ELLIS AVE S
# CONKLING PL W
# W GROVER ST
# VIEW AVE NW
# 11TH AVE W
# YALE AVE E
# PRINCETON AVE NE
# THORIN PL S
# W DRAVUS ST
# E CROCKETT ST
# COLORADO AVE S
# GREEN LAKE DR N
# FAIRVIEW AVE
# 52ND AVE NE
# S 105TH ST
# NE 96TH ST
# NW 52ND ST
# NW 45TH ST
# E ARTHUR PL
# 23RD AVE W
# 67TH AVE S
# W NEWTON ST
# S FRONT ST
# SW GRAHAM ST
# NW 91ST ST
# 8TH AVE N
# 12TH AVE W
# PUGET BLVD SW
# STURGUS AVE S
# NE 112TH ST
# GILMAN PL W
# LAKE CITY WAY NE
# LAWTON LN W
# S COURT ST
# NW 126TH ST
# S LAKE RIDGE DR
# N 81ST ST
# LENORA ST
# IAGO PL S
# NW 40TH ST
# WARD ST
# N 112TH ST
# SW HEINZE WAY
# WINONA AVE N
# 33RD PL NW
# SW ROXBURY ST
# E CHERRY ST
# VALLEY ST
# JEFFERSON ST
# NW PUGET DR
# ALTON PL NE
# SW CARROLL ST
# S KENYON WAY
# W JOHN ST
# W SHERIDAN ST
# POST AVE
# W PROSPECT ST
# BELMONT AVE
# CULPEPER CT NW
# ALDERBROOK PL NW
# PIKE ST
# SW MICHIGAN ST
# S ROXBURY ST
# UTAH AVE S
# SUNSET AVE SW
# 47TH AVE S
# S HARNEY ST
# E JAMES ST
# 35TH AVE NE
# 72ND AVE S
# 15TH PL S
# RAINIER AVE S
# SW AVALON WAY
# DURLAND AVE NE
# 47TH PL NE
# SEAVIEW TER SW
# CRESTWOOD DR S
# IRONDALE AVE W
# N 78TH ST
# UNIVERSITY VIEW PL NE
# NE ELK PL
# NW 61ST ST
# WOODLAND PL N
# N 84TH ST
# S LANDER ST
# S 115TH PL
# STROUD AVE N
# NW 96TH ST
# E MILLER ST
# S RAYMOND PL
# CHILBERG AVE SW
# W NEWELL ST
# S LAUREL ST
# NW 69TH ST
# SW VILLA PL
# S MONROE ST
# 52ND TER S
# S BATEMAN ST
# N 38TH CT
# SW 109TH ST
# WINSLOW PL N
# FAUNTLEE CREST SW
# SW SPOKANE ST
# NE BROCKMAN PL
# NE 53RD ST
# KNOX PL E
# SWIFT AVE S
# S MISSION DR
# SW 114TH ST
# S LEO ST
# CRESTMONT PL W
# S CONOVER WAY
# NE 41ST ST
# N 79TH ST
# MORLEY PL W
# S 118TH ST
# 70TH AVE S
# N 53RD ST
# MARS AVE S
# 51ST PL S
# S 114TH ST
# NE 108TH ST
# S SHELTON ST
# VASSAR AVE NE
# 24TH PL S
# BAINBRIDGE PL SW
# FERRY AVE SW
# BELL ST
# NW 41ST ST
# N 133RD ST
# 65TH AVE S
# NE 39TH ST
# S 110TH ST
# CARR PL N
# PEACH CT E
# N 100TH ST
# 56TH AVE S
# 54TH AVE SW
# 40TH AVE S
# NE BOAT ST
# S DONOVAN ST
# NE 103RD PL
# TALLMAN AVE NW
# 64TH AVE S
# N 68TH ST
# 40TH AVE E
# SPRING ST
# FOREST DR NE
# 27TH AVE SW
# DORFFEL DR E
# 21ST AVE W
# NE 114TH ST
# KEYSTONE PL N
# MAYES CT S
# CLAY ST
# DANIEL PL NE
# N 104TH ST
# E OLIVE PL
# 31ST AVE NW
# E EATON PL
# N 63RD ST
# BLAKELY PL NW
# 40TH AVE
# GRATTAN PL S
# E GWINN PL
# S GRATTAN ST
# 28TH AVE E
# BURTON PL W
# EDGEMONT PL W
# SW YANCY ST
# E ALLISON ST
# NE NORTHLAKE PL
# HARVARD AVE E
# NW CULBERTSON DR
# SW MONROE ST
# 33RD AVE
# S AVON ST
# 31ST AVE E
# 55TH AVE SW
# ALONZO AVE NW
# LOYAL WAY NW
# TERRY AVE N
# NW 115TH ST
# SW HORTON ST
# NW 88TH ST
# WOODROW PL E
# 19TH AVE
# N 76TH ST
# BELLEVUE PL E
# S GAZELLE ST
# MOUNT VIEW DR S
# MALDEN AVE E
# BELGROVE CT NW
# LAKEWOOD AVE S
# 13TH AVE NW
# NW 81ST ST
# NE 65TH ST
# CALIFORNIA LN SW
# N 136TH ST
# SW 97TH ST
# EAST LAURELHURST DR NE
# S BRANDON CT
# SW COLLEGE ST
# DRAVUS ST
# PONTIUS AVE N
# PULLMAN AVE NE
# NW 76TH ST
# FRANCIS AVE N
# ROY ST
# N 50TH ST
# NE 122ND ST
# S MOORE ST
# NE 84TH ST
# JONES PL NW
# 58TH AVE NE
# PADILLA PL S
# W PLYMOUTH ST
# 43RD AVE S
# CLAREMONT AVE S
# 9TH AVE S
# SAND POINT PL NE
# PARKVIEW AVE S
# N 40TH ST
# CONISTON RD NE
# NE 139TH ST
# SW IDA ST
# 13TH AVE W
# N 116TH ST
# PASADENA PL NE
# HOLDEN PL SW
# SW PENINSULA PL
# GLENRIDGE WAY SW
# S NEVADA ST
# MCGILVRA BLVD E
# S 126TH PL
# W SEMPLE ST
# SW PORTLAND ST
# 17TH AVE E
# NW 125TH ST
# 27TH AVE S
# 27TH AVE NW
# NE BLAKELEY ST
# 23RD AVE S
# NW 106TH ST
# WEST PARK DR E
# 44TH AVE W
# ARROYO BEACH PL SW
# NORTHWOOD RD NW
# NW BLAKELY CT
# NW NORTH BEACH DR
# SW MORGAN ST
# FARWELL PL SW
# SW BRACE POINT DR
# PAISLEY DR NE
# NE 38TH ST
# NE 76TH ST
# N 89TH ST
# 45TH AVE W
# 24TH AVE NW
# 65TH AVE NE
# BRADNER PL S
# SW PRITCHARD ST
# S MONTEREY PL
# BAYARD AVE NW
# NW 72ND ST
# S THAYER ST
# NE 81ST PL
# S WALDEN ST
# EVERETT AVE E
# S 116TH PL
# SW HOLDEN ST
# NE 56TH ST
# 15TH PL NE
# KENSINGTON PL N
# NW 47TH ST
# NW WOODBINE WAY
# BEDFORD CT NW
# 23RD AVE NW
# N 132ND ST
# S 107TH ST
# NW 103RD ST
# NE 133RD ST
# S 110TH PL
# NE 31ST ST
# W HALLADAY ST
# NE 55TH PL
# NW GOLDEN DR
# WHITMAN PL N
# BONAIR DR SW
# 63RD AVE S
# HOWE ST
# E EDGAR ST
# N 144TH ST
# W REPUBLICAN ST
# NW IONE PL
# PROSCH AVE W
# WABASH AVE S
# 32ND AVE NW
# NW 98TH ST
# CANTERBURY LN E
# 14TH AVE
# S BURNS ST
# HARVARD AVE
# LAKE DELL AVE
# TEXAS WAY W
# FOX AVE S
# N 96TH ST
# S DAY ST
# MOUNT ST HELENS PL S
# S BRADFORD ST
# NE 93RD ST
# SW DIRECTOR PL
# NE 134TH ST
# 58TH PL SW
# SW ADAMS ST
# N 98TH ST
# VALMAY AVE NW
# S BENNETT DR
# SW FOREST ST
# RUSSELL AVE NW
# W DENNY WAY
# S 121ST ST
# S RIVERSIDE DR
# NE 144TH ST
# E HIGH LN
# POWELL PL S
# 20TH PL S
# WINDERMERE DR E
# W ALOHA ST
# CLAREMONT PL S
# PALMER CT NW
# YALE AVE
# GOODWIN WAY NE
# WHALLEY PL W
# 25TH PL NE
# SW HEMLOCK WAY
# MONTVALE PL W
# 57TH PL SW
# 23RD AVE SW
# SW ORCHARD ST
# GALER PL N
# S HOLLY PARK DR
# WESTLAKE AVE N
# E JOHN ST
# E HURON ST
# WESTVIEW DR W
# NE NORTHLAKE WAY
# QUEEN ANNE DR
# FAIRMOUNT AVE SW
# 37TH AVE E
# HAHN PL S
# SW SULLIVAN ST
# HAROLD PL NE
# WOLCOTT AVE S
# UNIVERSITY WAY NE
# NE 74TH PL
# HILL TOP LN NW
# KELSEY LN SW
# NE FOREST VISTA
# BARTLETT AVE NE
# N 138TH ST
# 61ST AVE SW
# NE 143RD PL
# E MADISON ST
# NW 79TH ST
# E ALOHA ST
# 22ND CT NW
# 37TH PL S
# 23RD AVE E
# 39TH AVE
# LAKESIDE PL NE
# SW CALIFORNIA PL
# S WALLACE ST
# WELLESLEY WAY NE
# ELLERAY LN NE
# BOWEN PL S
# S PLUMMER ST
# 39TH PL SW
# INTERLAKEN PL E
# 17TH AVE W
# SIERRA DR S
# PINEHURST WAY NE
# YUKON AVE S
# NW 143RD ST
# RIDGE DR NE
# S CLOVERDALE ST
# NE 127TH ST
# SENECA ST
# SW 112TH PL
# PALM AVE SW
# E FOSTER ISLAND RD
# E YESLER WAY
# 58TH AVE S
# NE BELVOIR PL
# WAYNE PL N
# S OTHELLO ST
# 58TH AVE SW
# N 91ST ST
# S RIDGEWAY PL
# S JACKSON PL
# YALE AVE N
# FAIRVIEW PL N
# PURDUE AVE NE
# S 116TH ST
# S AUGUSTA ST
# NE LAURELCREST LN
# NE AMBLESIDE RD
# NE PENRITH RD
# NE 126TH ST
# 10TH PL W
# COURT PL
# WOODLAWN AVE NE
# SW CITY VIEW ST
# WHEELER ST
# SYCAMORE AVE NW
# 60TH PL S
# FULTON ST
# ROSLYN PL N
# POINT PL SW
# NE ELSHIN PL
# E REMINGTON CT
# NE 88TH PL
# NE 49TH ST
# S 120TH PL
# E MORLEY WAY
# S DELLA ST
# NW GREENBRIER WAY
# NW 89TH ST
# BLANCHARD ST
# GALE PL S
# E VALLEY ST
# NE 102ND ST
# 42ND PL NE
# 18TH PL NW
# 29TH PL SW
# NW 78TH ST
# S DOSE TER
# S BRADFORD PL
# 54TH PL SW
# E GLEN ST
# W ETRURIA ST
# 15TH AVE E
# CYRUS AVE NW
# 15TH AVE NE
# 44TH PL NE
# SW OCEAN VIEW DR
# FOREST CT SW
# NORTHSHIRE RD NW
# SHERMAN RD NW
# NORWOOD PL
# 11TH PL NW
# E MCGILVRA ST
# NEWPORT WAY
# SW PRESCOTT PL
# S 134TH PL
# FRATER AVE SW
# NW BRIGHT ST
# FRAZIER PL NW
# NW CENTRAL PL
# N 142ND ST
# SW FORNEY ST
# WAVERLY WAY E
# VASHON PL SW
# THORNDYKE AVE W
# 35TH AVE SW
# NW 118TH ST
# MERCER ST
# OSWEGO PL NE
# NE PARK PL
# SW NEVADA ST
# NW 93RD ST
# NE PACIFIC ST
# PREFONTAINE PL S
# W ARMOUR PL
# DETROIT AVE SW
# YALE TER E
# SHORELINE PARK DR NW
# S BOND ST
# W OHMAN PL
# MADISON CT
# NE KELDEN PL
# S VICTOR ST
# NW 99TH ST
# SPEAR PL S
# CRAWFORD PL
# EUCLID AVE
# S VALE ST
# WEST LAUREL DR NE
# S 123RD PL
# WINSTON AVE S
# 47TH PL SW
# MARSHALL AVE SW
# RED AVE E
# SAND POINT WAY NE
# PIEDMONT PL W
# HILLCREST AVE SW
# NW 140TH ST
# S BARTON PL
# ARMOUR ST
# N 93RD ST
# S DEAN CT
# BELLEVUE CT E
# N DOROTHY PL
# S 119TH ST
# NW SLOOP PL
# 2ND PL SW
# 7TH PL S
# 30TH AVE E
# 35TH PL NW
# S EASTWOOD DR
# BLAKE PL SW
# HOBART AVE SW
# DIVISION AVE NW
# SW ORLEANS ST
# MINOR AVE E
# N MOTOR PL
# S BENEFIT ST
# S WADSWORTH PL
# NW 86TH ST
# SW BEVERIDGE PL
# COMSTOCK ST
# BITTER PL N
# NE 106TH PL
# 50TH AVE S
# FLORA AVE S
# NW CANOE PL
# WILLIAMS AVE W
# S SHELL ST
# CHERRYLANE AVE S
# W TILDEN ST
# 33RD PL NE
# N 134TH ST
# NW FERN PL
# BLAIR TER S
# NE 90TH PL
# ELDORADO LN NW
# HOLLY PARK DR S
# S UPLAND RD
# SHAFFER AVE S
# HOLYOKE WAY S
# NE PARK POINT PL
# ARCH AVE SW
# LAUREL LN S
# WRIGHT AVE SW
# TERRACE DR NE
# N LUCAS PL
# ROYAL CT E
# 52ND PL SW
# WATERS AVE S
# 64TH AVE SW
# W HOOKER ST
# NE 128TH ST
# SW LANDER PL
# W PROSPER ST
# 83RD AVE S
# S HARDY ST
# GARDEN PL S
# NW NORTHWOOD RD
# RIDGEMONT WAY N
# W LYNN PL
# W FLORENTIA PL
# NE KESWICK DR
# RAINIER PL S
# BARNES AVE NW
# NE 135TH PL
# BIRCH AVE N
# STONE WAY N
# 59TH AVE SW
# DALLAS AVE S
# SW BRUCE ST
# S GARDEN ST
# SOUND VIEW TER W
# EAST LAUREL DR NE
# HEIGHTS PL SW
# NE MAPLE LEAF PL
# 26TH PL NW
# ALAMO PL S
# GRANDVIEW PL E
# AUGUSTA PL S
# NEBRASKA ST
# WAVERLY PL N
# N ARGYLE PL
# NE LATIMER PL
# W PLEASANT PL
# NE 104TH PL
# SW SHORE PL
# S RONALD DR
# CHEASTY BLVD S
# S EDDY CT
# 28TH AVE W
# E BOSTON TER
# 46TH PL SW
# 81ST PL S
# TAYLOR AVE N
# STENDALL PL N
# HALLECK AVE SW
# LAFAYETTE AVE S
# HARADEN PL S
# N MENFORD PL
# WOODWARD AVE S
# 71ST AVE S
# 6TH PL S
# MITHUN PL NE
# 55TH PL NE
# BISHOP PL W
# OAKHURST RD S
# N 94TH ST
# MATTHEWS PL NE
# SMITH ST
# LAKE WASHINGTON BLVD
# SW 101ST ST
# NICKLAS PL NE
# MARGINAL PL SW
# LAKE SHORE DR S
# N 113TH ST
# CHILBERG PL SW
# STANFORD AVE NE
# RICHWOOD AVE NW
# MERRILL LN NW
# SW 110TH PL
# 58TH PL S
# S PERRY ST
# 89TH AVE S
# 85TH AVE S
# NE 145TH ST
# 37TH PL E
# S 129TH PL
# 17TH PL S
# SW NIESZ CT
# NW ELFORD DR
# 8TH PL S
# S DEDHAM PL
# CECIL AVE S
# BLENHEIM DR E
# NW LEARY WAY
# E SUPERIOR ST
# MADRONA PL E
# KENILWORTH PL NE
# E BARCLAY CT
# RAILROAD AVE NE
# FISCHER PL NE
# SW ANGELINE ST
# W OLYMPIC PL
# S THISTLE PL
# BELMONT PL E
# S 134TH ST
# W EATON ST
# S RUSTIC RD
# S 135TH ST
# VINTON CT NW
# CANFIELD PL N
# 27TH PL W
# CORYELL CT E
# SW FRONT ST
# FRANKLIN PL E
# OLYMPIC VIEW PL N
# W ARGAND ST
# KENWOOD PL N
# LEWIS PL SW
# S 113TH ST
# HIAWATHA PL S
# S MORGAN PL
# NW 82ND ST
# 71ST PL S
# 47TH AVE W
# HEIGHTS AVE SW
# WEBSTER POINT RD NE
# S KEPPLER ST
# JAMES ST
# E FORD PL
# CREMONA ST
# WEST MARGINAL WAY S
# 65TH AVE SW
# PALMER DR NW
# NW 136TH ST
# 64TH AVE NE
# JUNEAU TER S
# NE TULANE PL
# S LILAC ST
# FULLERTON AVE
# CHATHAM DR S
# SW KENYON PL
# ERIE AVE
# MCGRAW PL
# LAKEMONT DR NE
# 56TH PL S
# LORENTZ PL N
# STURTEVANT AVE S
# DAVIS PL S
# 59TH AVE NE
# NW DOCK PL
# S 127TH PL
# SW 97TH CT
# 42ND PL S
# 10TH AVE NE
# WOODLAWN PL N
# FOREST HILL PL NW
# 31ST PL NE
# 74TH PL S
# NW MILFORD WAY
# 82ND PL S
# WEST LAURELHURST DR NE
# RIVIERA PL NE
# ALTAVISTA PL W
# N 56TH ST
# S NYE PL
# S OAKLAWN PL
# E ARLINGTON PL
# NW MARKET ST
# DEXTER WAY N
# S ANGEL PL
# 20TH PL NE
# S LESCHI PL
# NE 131ST PL
# 53RD CT NE
# 41ST PL NE
# FAUNTLEROY AVE SW
# 8TH CT NE
# WINGARD CT N
# WOODSIDE PL SW
# SW MILLS ST
# 57TH PL NE
# 24TH PL NE
# S 128TH ST
# TERRACE ST
# MAGNOLIA LN W
# COURTLAND PL N
# S HOLLY PL
# EAST PARK DR E
# N GREENWOOD CIR
# COVELLO DR S
# N 141ST CT
# ELM PL SW
# E NORTH ST
# W ROBERTS WAY
# SCHMITZ AVE SW
# 30TH PL SW
# S AVON CREST PL
# OHIO AVE S
# MADISON ST
# NW 55TH PL
# MOUNT BAKER DR S
# TERMINAL CT S
# 64TH PL S
# NW NORCROSS WAY
# NE URBAN VISTA
# 74TH LN S
# DEARBORN PL S
# HAMLET AVE S
# 37TH PL SW
# ARROWSMITH AVE S
# KILBOURNE CT SW
# THORNDYKE PL W
# NE NAOMI PL
# NE 96TH PL
# YALE PL E
# SW MARYLAND PL
# S ANGELO ST
# TILLICUM RD SW
# ORCHARD PL S
# SW CAMPBELL PL
# BELLEVUE AVE
# RUTAN PL SW
# SW HARBOR LN
# MARINE VIEW PL SW
# GOULD AVE S
# SW 107TH PL
# SW BEACH DRIVE TER
# S HAWTHORN RD
# EAST MARGINAL ER WAY S
# S SPOKANE NR ST
# NE 40TH ALLEY ST
# S BUSH PL
# 31ST WR AVE S
# S FOREST PL
# NAGLE PL
# BRIGHTON LN S
# N 131ST ST
# AQUA WAY S
# S OAKHURST PL
# NW 39TH ST
# 51ST PL SW
# W MCLAREN ST
# S FISHER PL
# N CLOGSTON WAY
# MORSE AVE S
# 4TH PL S
# 34TH CT S
# S ROSE CT
# W MONTFORT PL
# SW TEIG PL
# 81ST AVE S
# NW BRYGGER PL
# SW 102ND LN
# YAKIMA PL S
# S HOMER ST
# SW CANADA DR
# 38TH PL E
# MARMOUNT DR NW
# N NORTHLAKE WAY
# HOLLY CT SW
# SW LEDROIT PL
# WARREN PL
# S ORCHARD TER
# 19TH PL S
# STANTON PL NW
# W LAWTON CIR
# 44TH PL S
# CHICAGO CT S
# NW 126TH PL
# WOLFE PL W
# CREST PL S
# WEST MARGINAL PL S
# NE 116TH ST
# FUHRMAN AVE E
# W GOVERNMENT WAY
# STANLEY AVE S
# SW KLICKITAT WAY
# SEWARD PARK AVE S
# 9TH AVE N
# S BUDD CT
# N CANAL ST
# JILL PL S
# PARSHALL PL SW
# NW 137TH PL
# TAYLOR PL N
# HOLLY PL SW
# TEMPLE PL S
# 64TH LN S
# NW 114TH PL
# EASTLAKE AVE E
# NW 113TH PL
# 6TH PL SW
# 6TH CIR SW
# 4TH AVE SW
# DUWAMISH AV S ACCESS RD
# SW FLORIDA ST
# SW FLETCHER ST
# ISLAND DR S
# S BOZEMAN ST
# S FAIRBANKS ST
# RENTON PL S
# MERTON WAY S
# M L KING JR WAY S
# SW MACARTHUR LN
# TWIN MAPLE LN NE
# N 145TH ST
# BEVERIDGE PL SW
# 67TH PL S
# 64TH CT S
# I5 SB
# I5 NB
# I90 EB
# S 132ND ST
# FAIRVIEW NR AVE N
# 11TH AV NW ACCESS RD
# S SPOKANE TURN RD
# U-TURN RD
# WEST MARGINAL WAY SW
# 4TH AVE
# DENNY WAY
# WEST MARGINAL ER WAY SW
# BROAD ST
# NP RR
# CAROLINE AVE N
# S 118TH CT
# PORTAGE BAY PL E
# AURORA AVE N
# 15TH AVE W
# 8TH PL SW
# 9TH PL SW
# INTERLAKEN DR E
# NW 65TH CT
# PARKER CT NW
# E JOHN CT
# NW 65TH ST
# SW 96TH PL
# 79TH PL S
# SR520 WB
# SR520 EB
# I90 WB
# STATION 30 ACCESS RD
# S HENDERSON ST PED BR
# EMERSON TURN RD
# W GARFIELD ST ACCESS RD
# ROOSEVELT TURN RD NE
# I5 NB COLLECTOR
# I5 SB COLLECTOR
# SR522
# I5 EXPRESS
# BALLARD TERMINAL RR
# CMSP AND P RR
# LINK LIGHT RAIL
# BN RR
# NP RR BR
# WATERFRONT TROLLEY
# UP RR
# S 115TH LN
# MCCOY PL S
# 66TH LN S
# SPOKANE TURN RD
# CHELAN SR AVE SW
# SW CYCLE CT
# SR99 NB
# SR99 SB
# S GREENBELT STATION DR
# S COLUMBIAN WAY
# 7TH AVE N
# S VERN CT
# LANHAM PL SW
# SW 97TH PL
# 3RD LN SW
# ARBORETUM PL E
# W MERCER ST
# PUGET WAY SW
# BRIARCLIFF LN W
# W BRIARCLIFF LN
# SW BATAAN ST
# DISCOVERY PARK BLVD
# NW 114TH ST
# SW AUSTIN PL
# SW CHICAGO CT
# 26TH PL SW
# SW PORTLAND CT
# CROFT PL SW
# SW CAMBRIDGE PL
# MARCUS AVE S
# VALDEZ AVE S
# ALKI - HALLECK WKWY
# S 110TH CT
# S 108TH ST
# NE 109TH ST
# SW WHITE CENTER CUTOFF RD
# BOYER AVE E
# DELMAR DR E
# WEST SEATTLE BR WB
# EAST MARGINAL WAY S
# OLIVE WAY
# 2ND AVE
# MADRONA DR
# ALASKAN WAY
# E OLIVE WAY
# BOREN AVE
# ELLIOTT AVE
# 6TH AVE
# LEARY AVE NW
# YESLER WAY
# BRIDGE WAY N
# WEST VIEWMONT WAY W
# GREEN LAKE WAY N
# N 80TH ST
# DELRIDGE WAY SW
# MAGNOLIA BLVD W
# TRITON DR NW
# EAST GREEN LAKE DR N
# AIRPORT WAY S
# HIGHLAND PARK WAY SW
# N NORTHGATE WAY
# N 85TH ST
# HUNTER BLVD S
# VIEWMONT WAY W
# SW BARTON PL
# N PACIFIC ST
# W NICKERSON ST
# 23RD AVE
# W HARRISON ST
# FAIRVIEW AVE N
# CLISE PL W
# WILSON AVE S
# 20TH AVE W
# N 125TH ST
# OLYMPIC WAY W
# N MARKET ST
# WALL ST
# SEAVIEW AVE NW
# NICKERSON ST
# N 65TH ST
# NE NORTHGATE WAY
# N 130TH ST
# CARKEEK DR S
# NW 80TH ST
# S ALBRO PL
# COLLEGE WAY N
# MOUNT RAINIER DR S
# SYLVAN WAY SW
# BALLARD AVE NW
# HOWELL ST
# FLORENTIA ST
# BELLEVUE AVE E
# M L KING JR WAY
# ROOSEVELT WAY N
# S MICHIGAN ST
# SEAVIEW PL NW
# LAKESIDE AVE S
# BROADWAY
# LEARY WAY NW
# S BAILEY ST
# OLSON PL SW
# LAKE WASHINGTON BLVD E
# WESTERN AVE W
# ERSKINE WAY SW
# S MYRTLE PL
# KLICKITAT AVE SW
# COWEN PL NE
# POPLAR PL S
# E LAKE WASHINGTON BLVD
# UNION BAY PL NE
# SW WILDWOOD PL
# S ROYAL BROUGHAM WAY
# NW BALLARD WAY
# HARBOR AVE SW
# HOLMAN RD NW
# ELLIOTT AVE W
# EAST GREEN LAKE WAY N
# NW 100TH PL
# WEST GREEN LAKE WAY N
# EAST MONTLAKE PL E
# W MANOR PL
# 63RD AVE SW
# EASTLAKE AVE NE
# W COMMODORE WAY
# WEST GREEN LAKE DR N
# GLENN WAY SW
# M L KING JR WAY E
# FREMONT PL N
# LINCOLN PARK WAY SW
# BOREN AVE S
# WEST MONTLAKE PL E
# E JAMES WAY
# SW JACOBSEN RD
# W QUEEN ANNE DRIVEWAY
# NE PRINCETON WAY
# ALASKAN WAY S
# MONTLAKE BLVD E
# HOLMAN RD N
# N MIDVALE PL
# NW NEPTUNE PL
# CORLISS WAY N
# NW 36TH ST
# W EMERSON PL
# GOLDEN GARDENS DR NW
# CONDON WAY W
# WEEDIN PL NE
# ROSEMONT PL W
# MAGNOLIA BR
# W FLORENTIA ST
# CALIFORNIA WAY SW
# LAKE PARK DR S
# S GENESEE WAY
# TURNER WAY E
# DUMAR WAY SW
# HENDERSON PL SW
# DUWAMISH AVE S
# DES MOINES MEMORIAL DR S
# W EWING PL
# TOWER PL
# HIGH POINT DR SW
# 62ND AVE NE
# SW MARGUERITE CT
# CORGIAT DR S
# SEATTLE BLVD S
# SPORTSFIELD DR NE
# SW WILTON CT
# NE BANNER PL
# S 131ST ST
# VIEW LN SW
# S WILDWOOD LN
# S REDWING ST
# 80TH PL S
# LAKESIDE AVE
# S 124TH PL
# W EWING ST
# 88TH AVE S
# MURRAY AVE SW
# PARK POINT LN NE
# PARK POINT WAY NE
# NW 145TH ST
# NE PARK POINT DR
# LAKEVIEW BLVD E
# SW 111TH PL
# ROCKERY DR S
# 2ND LN SW
# SW 112TH LN
# SW 111TH LN
# 31ST PL S
# RAVENNA PL NE
# 35TH PL S
# BONAIR PL SW
# SW 113TH LN
# SW 96TH CIR
# 4TH PL SW
# 33RD PL S
# 34TH PL S
# S JUNIPER ST
# EDWARD DR S
# PARK DR S
# SW PORTER WAY
# 78TH AVE S
# 87TH AVE S
# FIRST HILL STREETCAR
# ATLAS PL SW
# MOUNT CLAIRE DR S
# HINDS PL S
# NE 104TH WAY
# BRYGGER DR W
# 41ST AVE W
# DARTMOUTH AVE W
# VOLUNTEER PARK RD
# NE SNOHOMISH LN
# WALLA WALLA RD NE
# 6TH PL NE
# 44TH PL SW
# 32ND PL SW
# 23RD CT NE
# SMITH PL
# N 114TH ST
# NE 73RD PL
# INVERNESS CT NE
# GATEWOOD RD SW
# ITHACA PL S
# VASHON VIEW SW
# NW 135TH PL
# PALATINE PL N
# S FOUNTAIN PL
# 31ST PL SW
# NW 108TH ST
# NW 104TH ST
# E FLORENCE CT
# LAFERN PL S
# 17TH PL NE
# ALPINE WAY NW
# S INGERSOLL PL
# ANTHONY PL S
# EAST STEVENS WAY NE
# RAINIER VISTA NE
# NE CHELAN LN
# PEND OREILLE RD NE
# RADFORD DR NE
# LK UNION PARK ACCESS RD
# SW KLICKITAT WY TURN RD
# E EDGEWATER PL
# 66TH AVE SW
# POWER AVE
# NOB HILL PL N
# PAR PL NE
# SW ENGLEWOOD ST
# S SNOQUALMIE PL
# BENTON PL SW
# EDGAR MARTINEZ DR S
# E LORETTA PL
# NORTHWOOD PL NW
# COTTAGE PL SW
# AUTUMN LN SW
# S BRANDON PL
# S ADDITION ST
# WARD PL
# UNIVERSITY BR
# 59TH AV SW TURN
# RAVENNA BV WB ACCESS RD
# SANDER RD S
# W GALER ST FLYOVER
# NICKERSON TURN RD
# UPLAND TER S
# NW 119TH ST
# 72ND PL S
# W ELMORE PL
# 22ND PL NE
# 64TH PL SW
# SEWARD PARK RD
# NE 52ND PL
# STADIUM PL S
# IDAHO AVE
# E NELSON PL
# CALIFORNIA AVE
# COLMAN DOCK ACCESS RD
# TERMINAL 5 ACCESS RD
# TERMINAL 5 EXIT RD
# KANSAS AVE
# IOWA ST
# NE RADFORD DR
# VICTORIA AVE SW
# ARCH PL SW
# SW 103RD PL
# JESSE AVE W
# WASHINGTON AVE W
# WASHINGTON AVE
# MONTANA CIR W
# RAILROAD WAY S
# ARBORETUM DR E
# E INTERLAKEN BLVD
# MONTANA CIR
# 21ST PL NE
# SW 110TH LN
# NE 85TH PL
# BANNER WAY NE
# S LK UNION STREETCAR
# GOVERNMENT LOCKS
# 84TH AVE S
# W MARGINAL TURN RD
# MONTLAKE BLVD NE
# WEST STEVENS WAY NE
# ALASKAN WAY W
# OKANOGAN LN NE
# MASON RD NE
# NE PACIFIC PL
# SW 116TH ST
# GILMAN DR W
# 11TH AV SW ACCESS RD
# TERMINAL 18 BR
# SHINKLE PL SW
# SW SYLVAN HEIGHTS DR
# MORROW LN
# FERRY PL NE
# KING LN NE
# WEST POINT AVE W
# MEMORIAL WAY NE
# NE MASON RD
# YAKIMA LN NE
# NE COLUMBIA RD
# PEND OREILLE PL NE
# NE SAN JUAN RD
# LINDSAY PL S
# AMHERST PL W
# GLENDALE WAY S
# BLAKELY - 12TH WKWY
# SW 98TH ST WKWY
# S MONROE ST ACCESS RD
# S MOUNT BAKER BLVD TUR RD
# E OLIVE ST WKWY
# SURBER DR NE
# SW 108TH PL
# 5TH LN SW
# CHERRYLANE PL S
# 10TH PL SW
# S FONTANELLE PL
# NW CANAL ST
# S CLOVERDALE PL
# BOWLYN PL S
# WARREN PL N
# W ARMORY WAY
# QUEEN ANNE AVE
# VILLAGE TER NE
# SCHMITZ PARK RD
# W VIEW PL
# BAY ST
# ERICKSON PL NE
# 7TH PL SW
# NE VILLAGE LN
# 86TH CT S
# VAN BUREN AVE W
# EASTLAKE PL NE
# TEMPLE PL
# THORNTON CREEK LN
# 46TH PL NE
# CALIFORNIA DR SW
# 23RD CT SW
# 8TH PL W
# GLENWILDE PL E
# E UNIVERSITY BLVD
# S BRADFORD ST WKWY
# S ORR ST
# ALLEY N OF GLENWILDE
# SW SEOLA LN
# MONORAIL
# VETERAN HOSPITAL DR
# CONVENTION PL
# WILCOX BR
# SR99 TUNNEL SB
# 21ST AV SW TURN
# 23RD WR AVE S
# PENNY DR
# MAGNOLIA BR WB
# MONTLAKE BR
# AURORA BR
# I90 EB TUNNEL
# SR509 SB
# WEST SEATTLE BR EB
# 58TH AV SW ACCESS RD
# SR509 NB
# 16TH AV S BR
# S GARDEN LOOP RD
# FIR ST
# WESTLAKE EAST RDWY AVE N
# 1ST AV S BR SB
# 1ST AV S BR NB
# FREMONT BR
# 68TH PL S
# MAGNOLIA WAY W
# 19TH AVE W
# W SEATTLE STADIUM AC RD
# VILLAGE CT NE
# S HOLGATE BR
# DUWAMISH AVE S BR
# NE NOAA DR
# NE 62ND ST PED BR
# NE 60TH ST PED BR
# 15TH PL W
# 18TH AVE W
# 24TH PL SW
# 33RD AV W PED BR
# SHORT PL S
# SW WESTBRIDGE PL
# ROSEBERG AVE S
# 22ND PL S
# S DEAN ST
# W MARINA PL
# 60TH LN S
# S 92ND PL
# S 95TH ST
# S 93RD ST
# TEXAS WAY
# SW 105TH PL
# S 111TH ST
# GLEN ACRES DR S
# EDGEWOOD AVE SW
# SW KLICKITAT WY ACC RD
# PERIMETER RD S
# PORTLAND ST
# NORTH KC AIRPORT ACC RD
# MAIN KC AIRPORT ACC RD
# GARFIELD PL NE
# NE SKAGIT LN
# NE GRANT LN
# 34TH CT W
# N 117TH PL
# N NORTHLAKE WAY ACC RD
# 37TH PL NW
# DILLING WAY
# 38TH AVE NW
# E SCHUBERT PL
# TAYLOR AVE
# SW 96TH LN
# S 104TH LN
# SW MAPLE WAY
# COMSTOCK PL
# S SPOKANE CR ST
# S 99TH ST
# SW SUMNER WAY
# BROOK AVE SW
# S MEDLEY CT
# SR99 TUNNEL NB
# S 133RD ST
# S ROYAL BROUGHAM WAY BR
# WELLER ST WALKWAY
# BALLARD BR
# S LUCILE ST BR
# S LYON CT
# DEXTER AVE
# S 118TH LN
# NE THORNTON PL
# MATTHEWS AVE NE
# E DENNY BLAINE PL
# 3RD PL SW
# BOREALIS AVE
# VISTA AVE S
# WESTWOOD VILLAGE CT SW
# WOODLAND PARK LOOP
# SOUND VIEW DR W
# HILLSIDE DR E
# W MARINA PARKING PL
# NE 125TH SR ST
# S ELIZABETH ST
# CLUB HOUSE DR
# OCEAN CT SW
# SYLVAN LN SW
# GOLD CT SW
# EXPEDIA GROUP WAY W
# I90 WB TUNNEL
# EXPEDIA PEDESTRIAN BR
# EXPEDIA GROUP WKWY
# DURLAND PL NE
# NW 134TH ST
# WASHINGTON PL E
# S FRINK PL
# NW 112TH PL
# S ROBERTO MAESTAS FEST ST
# BEACON WR AVE S
# SR99 NB COLLECTOR
# SR99 SB COLLECTOR
# NE WAHKIAKUM LN
# NE WAHKIAKUM RD
# COWLITZ RD NE
# NE LINCOLN WAY
# 13TH AVE NW PED BR
# NW 92ND ST WKWY
# COWLITZ RD NE WKWY
# SW SPOKANE ST BR
# LOGAN AVE W
# NE 87TH PL
# W THOMAS ST OVERPASS
# SW 99TH PL
# SW 98TH PL
# LITTLE CANOE CHANNEL NE
# UW WALKWAY
# KLICKITAT LN NE
# LENNY WILKENS WAY
# N PHINNEY WAY
# SCIENCE CENTER WKWY
# BROAD ST GREEN WKWY
# NE CLARK RD
# MASON PL NE
# SAN JUAN RD NE
# ADAMS LN NE
# SW 101ST PL
# SW 100TH PL
# NE COWLITZ RD
# 4TH LN SW
# MARY GATES MEMORIAL DR NE
# UNION ST STAIRS
# CANAL RD NE
# FRANKLIN PL NE
# FREMONT WAY N
# NE LEWIS LN
# NE STEVENS WAY
# NE THURSTON LN
# NE WHATCOM LN
# BENTON LN NE
# NE KITSAP LN
# SPOKANE LN NE
# GEORGE WASHINGTON LN NE
# ASOTIN PL NE
# WHITNEY PL NW
# SUMNER AVE SW
# OREGON AVE
# ILLINOIS AVE
# SW ANDOVER ST PED BR
# BERNIE WHITEBEAR WAY
# LAKE SHORE DR NE
# YESLER TERRACE ACC RD
# 17TH AVE NW WKWY
# CAROLINA ST
# SW BRONSON WAY
# LAWTONWOOD RD
# BAY TERRACE RD
# SW BERNICE PL
# COLMAN DOCK EXIT RD
# INTERLAKEN BLVD WKWY
# PIKE HILL CLIMB
# ALLEY RR TUNNEL ACC
# LENORA ST PED BR
# E BARBARA BAILEY WAY
# S 127TH LN
# GOLF DR S
# S ATLANTIC FLYOVER
# CAMPUS DR
# NW LOCKS PL
# NW 54TH SR ST
# 75TH PL S
# S 130TH PL
# ELLIOTT WAY
# HUMES PL W
# MARION ST PEDESTRIAN BR
# SW ROXBURY PL
# S RUGGLES ST
# SUE BIRD CT N
# MONTLAKE HOV RD
# S 99TH PL
# S 99TH PL ACCESS RD
# NE UNIVERSITY VILLAGE ST
# HOWELL PL
# TALARIS WAY
# E OLIVE LN
# 73RD PL S
# S 131ST CT
# JEFFERSON RD NE
# NORTHGATE TRANSIT RD
# JOHN LEWIS MEMORIAL BR
# NORTHGATE STATION RD
# PROMENADE PL NE
# NORTHGATE PZ
# NORTHGATE MALL
# S CARSTENS PL
# EVERGREEN PL
# S DORIS ST
# W MERCER PL
# 13TH PL S
# S CRESTON ST
# S RYAN WAY
# EASTLAKE AVE
# WESTWOOD PL NE
# SR520 PEDESTRIAN BR

# %%
gdf.head()
# Out:
#    f_intr_id  t_intr_id  snd_id  snd_feacode  citycode  stname_id  st_code  \
# 0      17740      17791   33478            5         1        566        0
# 1      11391      11295   20097            1         1        659        0
# 3      11695      11696   20460           77         1       1444       20
# 4       6257       6252    9237            1         1       2086        0
# 6      14191      14281   29554            1         1       1051        0
#
#    arterial_code  segment_type  agency_code  ...  r_zip  \
# 0              1             1            1  ...  98108
# 1              0             1            1  ...  98102
# 3              0             6            1  ...  98122
# 4              0             1            1  ...  98107
# 6              0             1            1  ...  98144
#
#               sndseg_update  compkey  comptype  unitid  unitid2  city_portion  \
# 0 2007-04-22 00:00:00+00:00     8460        68   04805     0820             S
# 1 2007-04-22 00:00:00+00:00     9236        68   05465     0010             E
# 3 2004-05-19 00:00:00+00:00        0         0       0        0             E
# 4 2012-10-12 00:00:00+00:00    18575        68   14630     0200            NW
# 6 2007-04-22 00:00:00+00:00    11712        68   08545     0320             S
#
#                                             geometry  ord_st_type  snd_group
# 0  LINESTRING (-122.32287 47.52982, -122.32289 47...          AVE          0
# 1  LINESTRING (-122.32402 47.61849, -122.32403 47...          AVE         11
# 3  LINESTRING (-122.30782 47.61411, -122.30749 47...           ST         12
# 4  LINESTRING (-122.38214 47.67456, -122.38476 47...           ST         15
# 6  LINESTRING (-122.29249 47.57475, -122.29171 47...          AVE         16
#
# [5 rows x 40 columns]

# %% [markdown]
# # SAVE AS A GDF - OVERWRITE

# %%
# file path
output_file_name = 'Street_Network_Database_Seattle_working.gpkg'

# %%
ofpn = os.path.join(file_path, output_file_name)

# %%
gdf.to_file(filename = ofpn, driver = 'GPKG', index = False)
